# %%
from google.colab import drive
import os
drive.mount("/content/drive")
os.chdir("drive/MyDrive/google_drive_hopkins/spring_24/neural_signals_class/hw2/")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.colab import drive
#       2 import os
#       3 drive.mount("/content/drive")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# !git clone https://github.com/BouchardLab/jPCA-1.git
# Out:
# Cloning into 'jPCA-1'...
# remote: Enumerating objects: 127, done.
# remote: Counting objects: 100% (127/127), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 127 (delta 68), reused 91 (delta 36), pack-reused 0
# Receiving objects: 100% (127/127), 770.10 KiB | 3.26 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
os.chdir("jPCA-1/")
# !pip install .
os.chdir("..")
# !git clone https://github.com/Esther-Whang-PhD/Neural_Signals_and_Computation_ewhang2_GitHUB
import os
os.chdir('Neural_Signals_and_Computation_ewhang2_GitHUB')
# Out:
# Processing /content/drive/MyDrive/google_drive_hopkins/spring_24/neural_signals_class/hw2/jPCA-1
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jPCA: filename=jPCA-0.0.1-py3-none-any.whl size=8663 sha256=642a6f9be2bdd05f80381ff50ac76d5e4a5d79f4c3283547934906238a587634
#   Stored in directory: /root/.cache/pip/wheels/80/bf/6d/bde70c86c772de141c18b1b7d7f2feb2d1ad8bc66e27f14a37
# Successfully built jPCA
# ...
#   Attempting uninstall: jPCA
#     Found existing installation: jPCA 0.0.1
#     Uninstalling jPCA-0.0.1:
#       Successfully uninstalled jPCA-0.0.1
# ...

# %% [markdown]
# Problem 1

# %%
from ewhang2_problem_1_ex_2 import Problem1
problem_1 = Problem1()

# %%
N = 100
problem_1.partA(N)

# %%
N = 20
M = 20
problem_1.partB(N,M)
# Out:
# MSE is
# 0.09419496796485671

# %%
N = 20
problem_1.partC(N)

# How accurate are the curves? What about for M = 2N? M = N/2? 
# Plot the estimates from Part C and Part B together. What do you notice
# about the estimates as the number of samples gets large?

# Response: The curves are not very accurate when M <= N. Estimates improve with larger sample size.

# %%
N = 20
problem_1.partD(N)
#How does this change the optimization?
#How about the estimated tuning curve?

# Response: It changes the optimization with the addition of the prior term
# Response: The Poisson MAP performs better than the Gaussian MAP
# Even with only M=N/2, the poisson MAP is respectably close to the estimated tuning curve
# There seems to be some issue at the M=N case? Couldn't figure out how to debug

# %%
N = 20
A = 0.01
regularization = 0.5
noise = 0.1
problem_1.partE(N, A, regularization, noise)
# Requires a large number of samples to make up for a small A
# At about 7500 times the dimension of the stimulus

# %% [markdown]
# Problem 2

# %%
from ewhang2_problem_2_ex_2 import Problem2
problem_2 = Problem2()
# Out:
# c:\Users\emwwm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\emwwm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\emwwm\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\gaussian_process\kernels.py:445: ConvergenceWarning: The optimal value found for dimension 0 of parameter length_scale is close to the specified lower bound 0.1. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# ...

# %%
problem_2.partA()

# %%
# Compute the Principal components of the PSTH matrix, both with and without smooth-
# ing. Look at the temporal principal components. Specifically, plot (side-by-side) the top 3 com-
# ponents as a 3D line plot. What do you notice?

problem_2.partB()

# Response: The smoothed PSTH is loopy, the regular PSTH is spiky
# Out:
# (400, 3)
# (400, 3)
